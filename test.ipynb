# %%
# !pip install --upgrade aiffel7

# %%
from aiffel7.get_tf_api_info import tf

x=tf()
print(x.get_info("keras.layers.Dropout"))
# Out:
# ===============================================
# * Document *
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout/
#
# * Git Hub source *
# [GitHub](https://github.com/keras-team/keras/tree/v2.14.0/keras/layers/regularization/dropout.py#L29-L135)
#
# * Arguments *
# tf.keras.layers.Dropout(
#     rate, noise_shape=None, seed=None, **kwargs
# )
#
# * Code Examples *
# >>>  tf.random.set_seed(0)
# >>>  layer = tf.keras.layers.Dropout(.2, input_shape=(2,))
# >>>  data = np.arange(10).reshape(5, 2).astype(np.float32)
# >>>  print(data)
# >>>  outputs = layer(data, training=True)
# >>>  print(outputs)
# ===============================================
# None

# %%
# !python setup.py sdist bdist_wheel
# !twine upload dist/*
# Out:
# running sdist
# running egg_info
# writing aiffel7.egg-info\PKG-INFO
# writing dependency_links to aiffel7.egg-info\dependency_links.txt
# writing requirements to aiffel7.egg-info\requires.txt
# writing top-level names to aiffel7.egg-info\top_level.txt
# reading manifest file 'aiffel7.egg-info\SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'aiffel7.egg-info\SOURCES.txt'
# running check
# creating aiffel7-0.3.2
# creating aiffel7-0.3.2\aiffel7
# creating aiffel7-0.3.2\aiffel7.egg-info
# copying files to aiffel7-0.3.2...
# copying LICENSE -> aiffel7-0.3.2
# copying README.md -> aiffel7-0.3.2
# copying setup.py -> aiffel7-0.3.2
# copying aiffel7\__init__.py -> aiffel7-0.3.2\aiffel7
# copying aiffel7\get_tf_api_info.py -> aiffel7-0.3.2\aiffel7
# copying aiffel7\history_graph.py -> aiffel7-0.3.2\aiffel7
# copying aiffel7\my_module.py -> aiffel7-0.3.2\aiffel7
# copying aiffel7.egg-info\PKG-INFO -> aiffel7-0.3.2\aiffel7.egg-info
# copying aiffel7.egg-info\SOURCES.txt -> aiffel7-0.3.2\aiffel7.egg-info
# copying aiffel7.egg-info\dependency_links.txt -> aiffel7-0.3.2\aiffel7.egg-info
# copying aiffel7.egg-info\requires.txt -> aiffel7-0.3.2\aiffel7.egg-info
# copying aiffel7.egg-info\top_level.txt -> aiffel7-0.3.2\aiffel7.egg-info
# Writing aiffel7-0.3.2\setup.cfg
# Creating tar archive
# removing 'aiffel7-0.3.2' (and everything under it)
# running bdist_wheel
# running build
# running build_py
# copying aiffel7\get_tf_api_info.py -> build\lib\aiffel7
# copying aiffel7\history_graph.py -> build\lib\aiffel7
# copying aiffel7\my_module.py -> build\lib\aiffel7
# installing to build\bdist.win-amd64\wheel
# running install
# running install_lib
# creating build\bdist.win-amd64\wheel
# creating build\bdist.win-amd64\wheel\aiffel7
# copying build\lib\aiffel7\get_tf_api_info.py -> build\bdist.win-amd64\wheel\.\aiffel7
# copying build\lib\aiffel7\history_graph.py -> build\bdist.win-amd64\wheel\.\aiffel7
# copying build\lib\aiffel7\my_module.py -> build\bdist.win-amd64\wheel\.\aiffel7
# copying build\lib\aiffel7\__init__.py -> build\bdist.win-amd64\wheel\.\aiffel7
# creating build\bdist.win-amd64\wheel\tripleyoung
# copying build\lib\tripleyoung\my_module.py -> build\bdist.win-amd64\wheel\.\tripleyoung
# copying build\lib\tripleyoung\__init__.py -> build\bdist.win-amd64\wheel\.\tripleyoung
# running install_egg_info
# Copying aiffel7.egg-info to build\bdist.win-amd64\wheel\.\aiffel7-0.3.2-py3.12.egg-info
# running install_scripts
# creating build\bdist.win-amd64\wheel\aiffel7-0.3.2.dist-info\WHEEL
# creating 'dist\aiffel7-0.3.2-py3-none-any.whl' and adding 'build\bdist.win-amd64\wheel' to it
# adding 'aiffel7/__init__.py'
# adding 'aiffel7/get_tf_api_info.py'
# adding 'aiffel7/history_graph.py'
# adding 'aiffel7/my_module.py'
# adding 'tripleyoung/__init__.py'
# adding 'tripleyoung/my_module.py'
# adding 'aiffel7-0.3.2.dist-info/LICENSE'
# adding 'aiffel7-0.3.2.dist-info/METADATA'
# adding 'aiffel7-0.3.2.dist-info/WHEEL'
# adding 'aiffel7-0.3.2.dist-info/top_level.txt'
# adding 'aiffel7-0.3.2.dist-info/RECORD'
# removing build\bdist.win-amd64\wheel
# c:\Users\dudnj\.conda\envs\aiffel2\Lib\site-packages\setuptools\_distutils\cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# Uploading distributions to https://upload.pypi.org/legacy/
# Uploading aiffel7-0.1-py3-none-any.whl
#
#   0% ---------------------------------------- 0.0/4.1 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/4.1 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/4.1 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/4.1 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/4.1 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/4.1 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/4.1 kB • --:-- • ?
# 100% ---------------------------------------- 4.1/4.1 kB • 00:00 • ?
# 100% ---------------------------------------- 4.1/4.1 kB • 00:00 • ?
# 100% ---------------------------------------- 4.1/4.1 kB • 00:00 • ?
# 100% ---------------------------------------- 4.1/4.1 kB • 00:00 • ?
# 100% ---------------------------------------- 4.1/4.1 kB • 00:00 • ?
# Uploading aiffel7-0.1.1-py3-none-any.whl
#
#   0% ---------------------------------------- 0.0/4.7 kB • --:-- • ?
# 100% ---------------------------------------- 4.7/4.7 kB • 00:00 • ?
# 100% ---------------------------------------- 4.7/4.7 kB • 00:00 • ?
# 100% ---------------------------------------- 4.7/4.7 kB • 00:00 • ?
# Uploading aiffel7-0.3.2-py3-none-any.whl
#
#   0% ---------------------------------------- 0.0/6.7 kB • --:-- • ?
# 100% ---------------------------------------- 6.7/6.7 kB • 00:00 • ?
# 100% ---------------------------------------- 6.7/6.7 kB • 00:00 • ?
# 100% ---------------------------------------- 6.7/6.7 kB • 00:00 • ?
# 100% ---------------------------------------- 6.7/6.7 kB • 00:00 • ?
# 100% ---------------------------------------- 6.7/6.7 kB • 00:00 • ?
# 100% ---------------------------------------- 6.7/6.7 kB • 00:00 • ?
# 100% ---------------------------------------- 6.7/6.7 kB • 00:00 • ?
# 100% ---------------------------------------- 6.7/6.7 kB • 00:00 • ?
# 100% ---------------------------------------- 6.7/6.7 kB • 00:00 • ?
# 100% ---------------------------------------- 6.7/6.7 kB • 00:00 • ?
# 100% ---------------------------------------- 6.7/6.7 kB • 00:00 • ?
# 100% ---------------------------------------- 6.7/6.7 kB • 00:00 • ?
# 100% ---------------------------------------- 6.7/6.7 kB • 00:00 • ?
# 100% ---------------------------------------- 6.7/6.7 kB • 00:00 • ?
# 100% ---------------------------------------- 6.7/6.7 kB • 00:00 • ?
# 100% ---------------------------------------- 6.7/6.7 kB • 00:00 • ?
# 100% ---------------------------------------- 6.7/6.7 kB • 00:00 • ?
# Uploading aiffel7-0.1.1.tar.gz
#
#   0% ---------------------------------------- 0.0/4.1 kB • --:-- • ?
# 100% ---------------------------------------- 4.1/4.1 kB • 00:00 • ?
# 100% ---------------------------------------- 4.1/4.1 kB • 00:00 • ?
# 100% ---------------------------------------- 4.1/4.1 kB • 00:00 • ?
# 100% ---------------------------------------- 4.1/4.1 kB • 00:00 • ?
# 100% ---------------------------------------- 4.1/4.1 kB • 00:00 • ?
# Uploading aiffel7-0.1.tar.gz
#
#   0% ---------------------------------------- 0.0/3.9 kB • --:-- • ?
# 100% ---------------------------------------- 3.9/3.9 kB • 00:00 • ?
# 100% ---------------------------------------- 3.9/3.9 kB • 00:00 • ?
# 100% ---------------------------------------- 3.9/3.9 kB • 00:00 • ?
# Uploading aiffel7-0.3.2.tar.gz
#
#   0% ---------------------------------------- 0.0/5.5 kB • --:-- • ?
# 100% ---------------------------------------- 5.5/5.5 kB • 00:00 • ?
# 100% ---------------------------------------- 5.5/5.5 kB • 00:00 • ?
# 100% ---------------------------------------- 5.5/5.5 kB • 00:00 • ?
# 100% ---------------------------------------- 5.5/5.5 kB • 00:00 • ?
# 100% ---------------------------------------- 5.5/5.5 kB • 00:00 • ?
# 100% ---------------------------------------- 5.5/5.5 kB • 00:00 • ?
# 100% ---------------------------------------- 5.5/5.5 kB • 00:00 • ?
# 100% ---------------------------------------- 5.5/5.5 kB • 00:00 • ?
# 100% ---------------------------------------- 5.5/5.5 kB • 00:00 • ?
#
# View at:
# https://pypi.org/project/aiffel7/0.1/
# https://pypi.org/project/aiffel7/0.3.2/
# https://pypi.org/project/aiffel7/0.1.1/

# %%
# !twine upload dist/*
# Out:
# Uploading distributions to https://upload.pypi.org/legacy/
# Uploading aiffel7-0.4.3-py3-none-any.whl
#
#   0% ---------------------------------------- 0.0/8.5 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/8.5 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/8.5 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/8.5 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/8.5 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/8.5 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/8.5 kB • --:-- • ?
# 100% ---------------------------------------- 8.5/8.5 kB • 00:00 • ?
# 100% ---------------------------------------- 8.5/8.5 kB • 00:00 • ?
# 100% ---------------------------------------- 8.5/8.5 kB • 00:00 • ?
# 100% ---------------------------------------- 8.5/8.5 kB • 00:00 • ?
# 100% ---------------------------------------- 8.5/8.5 kB • 00:00 • ?
# WARNING  Error during upload. Retry with the --verbose option for more details.
# ERROR    HTTPError: 400 Bad Request from https://upload.pypi.org/legacy/
#          File already exists. See https://pypi.org/help/#file-name-reuse for
#          more information.
